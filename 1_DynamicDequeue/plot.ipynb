# %%
import matplotlib.pyplot as plt 

file1 = open("linear.txt","r")
linear = file1.read()
file1.close()

file2 = open("expo.txt","r")
expo = file2.read()
file2.close()

plt.plot(linear.split())
plt.plot(expo.split())
plt.xlabel("n = 2^x")
plt.ylabel("Time Taken")
plt.title("CS293 Assignment-1 DynamicDequeue")
plt.legend(["linear size increase","exponential size increase"])
